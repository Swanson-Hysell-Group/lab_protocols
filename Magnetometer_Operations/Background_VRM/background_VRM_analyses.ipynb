# %% [markdown]
# # This notebook is for analyzing the backgournd drifting of the three axes SQUIDs on the magnetometer
#
# - 05/27/2021 overnight VRM acquisition recorded in file "background_measurement_05272021.csv"

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %% [markdown]
# ## 2021 May background test

# %%
bacckground_05272021 = pd.read_csv('background_measurement_05272021.csv', header=0)
bacckground_05272021.head()
# Out:
#    Time (s)         x         y         z
# 0     9.999  0.156946 -0.327400 -0.781302
# 1    22.417  0.157196 -0.327193 -0.782941
# 2    34.851  0.157105 -0.327285 -0.781470
# 3    47.284  0.157037 -0.327446 -0.779113
# 4    59.667  0.157014 -0.327423 -0.778310

# %%
plt.figure(figsize=(18, 8))
plt.scatter(bacckground_05272021['Time (s)'], bacckground_05272021['x'], label='x', color = 'C0')
plt.scatter(bacckground_05272021['Time (s)'], bacckground_05272021['y'], label='y', color = 'C1')
plt.scatter(bacckground_05272021['Time (s)'], bacckground_05272021['z'], label='z', color = 'C2')

plt.title('time series background drfting on all three axes', fontsize=18)
plt.xlabel('time (s)', fontsize=12)
plt.ylabel('background reading', fontsize=12)
plt.legend()
plt.savefig('all_axes_drift.pdf')
plt.show()

# %%
plt.figure(figsize=(18, 8))
plt.scatter(bacckground_05272021['Time (s)'], bacckground_05272021['x'], label='x', color = 'C0')

plt.title('time series background drfting on x axis', fontsize=18)
plt.xlabel('time (s)', fontsize=12)
plt.ylabel('background reading', fontsize=12)
plt.legend()
plt.savefig('x_axis_drift.pdf')
plt.show()

# %%
plt.figure(figsize=(18, 8))
plt.scatter(bacckground_05272021['Time (s)'], bacckground_05272021['y'], label='y', color = 'C1')

plt.title('time series background drfting on y axis', fontsize=18)
plt.xlabel('time (s)', fontsize=12)
plt.ylabel('background reading', fontsize=12)
plt.legend()
plt.savefig('y_axis_drift.pdf')
plt.show()

# %%
plt.figure(figsize=(18, 8))
plt.scatter(bacckground_05272021['Time (s)'], bacckground_05272021['z'], label='z', color = 'C2')

plt.title('time series background drfting on z axis', fontsize=18)
plt.xlabel('time (s)', fontsize=12)
plt.ylabel('background reading', fontsize=12)
plt.legend()
plt.savefig('z_axis_drift.pdf')
plt.show()

# %% [markdown]
# ## 2021 Oct background test

# %%
bacckground_2021oct = pd.read_csv('2021_Oct_VRM_2.csv', header=0)
bacckground_2021oct.head()
# Out:
#    Time (s)         x         y         z
# 0    10.000  0.472410 -0.534456 -0.373608
# 1    22.359  0.472364 -0.534479 -0.373307
# 2    34.648  0.472319 -0.534433 -0.373257
# 3    46.937  0.472250 -0.534433 -0.373240
# 4    59.226  0.472250 -0.534387 -0.373508

# %%
plt.figure(figsize=(18, 8))
plt.scatter(bacckground_2021oct['Time (s)'], bacckground_2021oct['x'], label='x', color = 'C0', s=5)
plt.scatter(bacckground_2021oct['Time (s)'], bacckground_2021oct['y'], label='y', color = 'C1', s=5)
plt.scatter(bacckground_2021oct['Time (s)'], bacckground_2021oct['z'], label='z', color = 'C2', s=5)

plt.title('time series background drfting on all three axes', fontsize=18)
plt.xlabel('time (s)', fontsize=12)
plt.ylabel('background reading', fontsize=12)
# plt.yscale('log')
# plt.xticks([3600, 3600*10, 3600*24, 3600*24*2, 3600*24*3, 3600*24*4, 3600*24*5, 3600*24*6, 3600*24*7, 3600*24*8, 3600*24*9, 3600*24*10], 
#            ['1h', '10h', '24h', '48h', '3d', '4d', '5d', '6d', '7d', '8d', '9d', '10d'])
plt.legend()
# plt.savefig('all_axes_drift.pdf')
plt.show()

# %%
bacckground_2021oct = bacckground_2021oct[bacckground_2021oct['x'] > 0]

plt.figure(figsize=(18, 8))
plt.scatter(bacckground_2021oct['Time (s)'], bacckground_2021oct['x'], label='x', color = 'C0')

plt.title('time series background drfting on x axis', fontsize=18)
plt.xlabel('time (s)', fontsize=12)
plt.ylabel('background reading', fontsize=12)
plt.legend()
# plt.savefig('x_axis_drift.pdf')
plt.show()

# %%
plt.figure(figsize=(18, 8))
plt.scatter(bacckground_2021oct['Time (s)'], bacckground_2021oct['y'], label='y', color = 'C1')

# plt.xticks([3600, 3600*10, 3600*24, 3600*24*2, 3600*24*3, 3600*24*4, 3600*24*5, 3600*24*6, 3600*24*7, 3600*24*8, 3600*24*9, 3600*24*10], 
#            ['1h', '10h', '24h', '48h', '3d', '4d', '5d', '6d', '7d', '8d', '9d', '10d'])
plt.title('time series background drfting on y axis', fontsize=18)
plt.xlabel('time (s)', fontsize=12)
plt.ylabel('background reading', fontsize=12)
plt.legend()
# plt.savefig('y_axis_drift.pdf')
plt.show()

# %%
plt.figure(figsize=(18, 8))
plt.scatter(bacckground_2021oct['Time (s)'], bacckground_2021oct['z'], label='z', color = 'C2')
# plt.xticks([3600, 3600*10, 3600*24, 3600*24*2, 3600*24*3, 3600*24*4, 3600*24*5, 3600*24*6, 3600*24*7, 3600*24*8, 3600*24*9, 3600*24*10], 
#            ['1h', '10h', '24h', '48h', '3d', '4d', '5d', '6d', '7d', '8d', '9d', '10d'])
plt.title('time series background drfting on z axis', fontsize=18)
plt.xlabel('time (s)', fontsize=12)
plt.ylabel('background reading', fontsize=12)
plt.legend()
# plt.savefig('z_axis_drift.pdf')
plt.show()
